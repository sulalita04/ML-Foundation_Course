# %%
#1. Import matplotlib and plot a basic line graph.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
plt.plot(x, y)
plt.show()

# %%
#2. Plot two lines on the same graph.
x = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]
y2 = [2, 3, 5, 7, 11]
plt.plot(x, y1, label='Squares')
plt.plot(x, y2, label='Primes')
plt.legend()
plt.show()

# %%
#3. Change the color of a line plot.
plt.plot(x, y1, color='green')
plt.show()

# %%
#4. Use markers on a line plot.
plt.plot(x, y2, marker='o')
plt.show()

# %%
#5. Change line style (dashed, dotted, etc.).
plt.plot(x, y1, linestyle='--')
plt.show()

# %%
#6. Add title to a plot.
plt.plot(x, y2)
plt.title("Prime Numbers")
plt.show()

# %%
#7. Label the x-axis and y-axis.
plt.plot(x, y1)
plt.xlabel("X-axis")
plt.ylabel("Square of X")
plt.show()

# %%
#8. Add a legend to your plot.
plt.plot(x, y1, label='Squares')
plt.plot(x, y2, label='Primes')
plt.legend()
plt.show()

# %%
#9. Plot a simple bar chart.
x = ['A', 'B', 'C']
y = [10, 20, 15]
plt.bar(x, y)
plt.title("Simple Bar Chart")
plt.show()

# %%
#10. Change bar colors in a bar chart.
plt.bar(x, y, color=['red', 'green', 'blue'])
plt.title("Colored Bar Chart")
plt.show()

# %%
#11.Create a horizontal bar chart.
plt.barh(x, y, color='purple')
plt.title("Horizontal Bar Chart")
plt.show()

# %%
#12. Plot a histogram. 
data = np.random.randn(1000)
plt.hist(data)
plt.title("Histogram")
plt.show()

# %%
#13. Change the number of bins in a histogram. 
plt.hist(data, bins=30)
plt.title("Histogram with 30 Bins")
plt.show()

# %%
#14. Add gridlines to your plot. 
plt.plot([1,2,3], [4,5,6])
plt.grid(True)
plt.title("Plot with Gridlines")
plt.show()

# %%
#15.Save your plot as an image file.
plt.plot([1,2,3], [4,5,6])
plt.savefig('my_plot.png')

# %%
#16.Plot a pie chart.
labels = ['A', 'B', 'C']
sizes = [30, 40, 30]
plt.pie(sizes)
plt.title("Pie Chart")
plt.show()

# %%
#17. Add labels to pie chart sections.
plt.pie(sizes, labels=labels)
plt.title("Pie Chart with Labels")
plt.show()

# %%
#18. Add percentage to pie chart sections.
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title("Pie Chart with Percentages")
plt.show()

# %%
#19.Plot a scatter plot.
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x, y)
plt.title("Scatter Plot")
plt.show()

# %%
#20.Change marker size in scatter plot.
plt.scatter(x, y, s=100)  # s = size
plt.title("Scatter Plot with Bigger Markers")
plt.show()

# %%
#21.Change marker color in scatter plot.
plt.scatter(x, y, c='red')
plt.title("Scatter Plot with Red Markers")
plt.show()

# %%
#22.Plot multiple scatter plots in one figure.
plt.scatter(x, y, label="Group 1")
plt.scatter(x+0.1, y+0.1, label="Group 2")
plt.legend()
plt.show()

# %%
#23.Use subplot to show two plots side-by-side.
plt.subplot(1, 2, 1)
plt.plot([1,2,3])
plt.subplot(1, 2, 2)
plt.plot([3,2,1])
plt.show()

# %%
#24.Use subplot to show four plots in a 2x2 grid.
for i in range(1, 5):
    plt.subplot(2, 2, i)
    plt.plot([i, i+1, i+2])
plt.show()

# %%
#25.Plot a sine wave using numpy.
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title("Sine Wave")
plt.show()

# %%
#26.Customize tick marks on x and y axis.
plt.plot(x, y)
plt.xticks([0, np.pi, 2*np.pi], ['0', 'pi', '2pi'])
plt.yticks([-1, 0, 1])
plt.show()

# %%
#27.Rotate x-axis labels.
plt.bar(['A', 'B', 'C'], [10, 20, 15])
plt.xticks(rotation=45)
plt.show()

# %%
#28.Add annotation to your plot.
plt.plot(x, y)
plt.annotate('Peak', xy=(np.pi/2, 1), xytext=(2, 1.2),
             arrowprops=dict(facecolor='black'))
plt.show()

# %%
#29.Draw a filled area under a line (fill_between).
plt.plot(x, y)
plt.fill_between(x, y, alpha=0.3)
plt.show()

# %%
#30.Use different figure sizes.
plt.figure(figsize=(10, 4))
plt.plot(x, y)
plt.show()

# %%
#31.Plot a stacked bar chart.
A = [3, 4, 5]
B = [2, 3, 4]
x = np.arange(3)
plt.bar(x, A, label="A")
plt.bar(x, B, bottom=A, label="B")
plt.legend()
plt.show()

# %% [markdown]
# # 32.Plot 11111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111grouped bar charts.

# %%
#32.Plot grouped bar charts.
bar_width = 0.35
x = np.arange(3)
plt.bar(x, A, width=bar_width, label="A")
plt.bar(x + bar_width, B, width=bar_width, label="B")
plt.legend()
plt.show()

# %%
#33.Customize legend location.
plt.plot([1,2,3], label="Line")
plt.legend(loc='upper left')
plt.show()

# %%
#34.Use different font styles and sizes.
plt.title("Title", fontsize=14, fontstyle='italic')
plt.plot([1,2,3])
plt.show()

# %%
#35.Change background color of plot.
fig = plt.figure()
fig.patch.set_facecolor('lightblue')
plt.plot([1,2,3])
plt.show()

# %%
#36.Use plt.style to apply predefined styles.
plt.style.use('ggplot')
plt.plot([1,2,3])
plt.show()

# %%
#37.Create a plot with dual y-axis.
x = np.arange(0, 10, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.plot(x, y1, 'g-')
ax2.plot(x, y2, 'b-')

ax1.set_ylabel('sin', color='g')
ax2.set_ylabel('cos', color='b')
plt.show()

# %%
#38.Set axis limits with xlim and ylim.
plt.plot(x, y)
plt.xlim(0, 3)
plt.ylim(-1, 1)
plt.show()

# %%
#39.Hide axis ticks and labels.
plt.plot([1,2,3])
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#40.Create a 3D plot using matplotlib.
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

ax.plot_surface(X, Y, Z, cmap='viridis')
plt.show()

# %%
#41.Plot a heatmap using imshow.
data = np.random.rand(10, 10)
plt.imshow(data, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
#42.Use color maps in heatmaps.
plt.imshow(data, cmap='coolwarm')
plt.colorbar()
plt.show()

# %%
#43.Draw a box plot.
data = np.random.randn(100)
plt.boxplot(data)
plt.show()

# %%
#44.Draw a violin plot.
plt.violinplot(data)
plt.show()

# %%
#45.Add error bars to bar charts.
y = [20, 35, 30]
error = [2, 3, 4]
x = np.arange(len(y))  
plt.bar(x, y, yerr=error, capsize=5)
plt.xticks(x, ['A', 'B', 'C']) 
plt.ylabel('Value')
plt.show()

# %%
#46.Customize plot borders/spines.
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.plot([1,2,3])
plt.show()

# %%
#47.Create a donut chart (pie chart with a hole).
plt.pie(sizes, labels=labels, autopct='%1.1f%%', wedgeprops=dict(width=0.4))
plt.show()

# %%
#48.Use pandas DataFrame to plot data.

df = pd.DataFrame({'A': [1, 3, 5], 'B': [2, 4, 6]})
df.plot()
plt.show()

# %%
#49.Customize plot titles with math text.
plt.title(r'$\alpha^2 + \beta^2 = \gamma^2$')
plt.plot([1,2,3])
plt.show()

# %%
#50.Plot real-world data from a CSV file.
df = pd.read_csv('Downloads//Obesity Classification.csv')  # Replace with actual path
df.plot()
plt.show()
